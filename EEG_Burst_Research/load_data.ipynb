# %%
from scipy.io import loadmat
import numpy as np

def load_mat_file(file_path):
    """
    Load a MATLAB .mat file and convert its contents to a Python dictionary
    with NumPy arrays.

    Parameters:
    file_path (str): The path to the .mat file.

    Returns:
    dict: A dictionary containing the data from the .mat file.
    """
    mat_data = loadmat(file_path)
    
    # Remove MATLAB-specific entries
    mat_data = {key: value for key, value in mat_data.items() if not key.startswith('__')}
    
    # Convert MATLAB arrays to NumPy arrays
    for key in mat_data:
        if isinstance(mat_data[key], np.ndarray):
            mat_data[key] = np.array(mat_data[key])
    
    return mat_data['val']

# %%
import wfdb

def load_hea_file(file_path):
    rd = wfdb.rdheader(file_path)
    
    return rd.fs, rd.sig_name, rd.n_sig, rd.units

# %%
import numpy as np
from scipy.signal import resample as sp_resample

def resample_eeg(eeg_data, fs_orig, fs_new):
    # eeg_data shape: (n_channels, n_samples)
    n_new = int(eeg_data.shape[1] * fs_new / fs_orig)
    return sp_resample(eeg_data, n_new, axis=1)

# %%
import mne
import numpy as np

def apply_eeg_filters(eeg, fs):
    # eeg shape: (n_channels, n_samples)
    # Scale normalized units to a range appropriate for MNE (convert to ~Volts range)
    eeg_scaled = eeg * 1e-6
    
    info = mne.create_info(
        ch_names=[f"ch{i}" for i in range(eeg_scaled.shape[0])],
        sfreq=fs,
        ch_types="eeg",
    )
    raw = mne.io.RawArray(eeg_scaled, info)  # no transpose; matches (channels, samples)
    raw.filter(l_freq=0.5, h_freq=50, fir_design="firwin")
    raw.notch_filter(freqs=60)
    
    # Scale back to original range
    return raw.get_data() * 1e6  # stays (n_channels, n_samples)

# %%
import numpy as np

def make_bipolar(eeg, ch_names):
    """
    eeg: (n_channels, n_samples) aligned to ch_names
    ch_names: list of labels in eeg row order
    returns: (bipolar_eeg, bipolar_names)
    """
    name_to_idx = {n: i for i, n in enumerate(ch_names)}

    pairs = [
        ("Fp1-F7", "Fp1", "F7"),
        ("F7-T3",  "F7",  "T3"),
        ("T3-T5",  "T3",  "T5"),
        ("T5-O1",  "T5",  "O1"),

        ("Fp2-F8", "Fp2", "F8"),
        ("F8-T4",  "F8",  "T4"),
        ("T4-T6",  "T4",  "T6"),
        ("T6-O2",  "T6",  "O2"),

        ("Fp1-F3", "Fp1", "F3"),
        ("F3-C3",  "F3",  "C3"),
        ("C3-P3",  "C3",  "P3"),
        ("P3-O1",  "P3",  "O1"),

        ("Fp2-F4", "Fp2", "F4"),
        ("F4-C4",  "F4",  "C4"),
        ("C4-P4",  "C4",  "P4"),
        ("P4-O2",  "P4",  "O2"),

        ("Fz-Cz",  "Fz",  "Cz"),
        ("Cz-Pz",  "Cz",  "Pz"),
        ("T3-C3",  "T3",  "C3"),  # optional alt: T3-C3 vs. T3-F7
    ]

    bipolar = []
    bipolar_names = []
    for new_name, a, b in pairs:
        ai, bi = name_to_idx[a], name_to_idx[b]
        bipolar.append(eeg[ai] - eeg[bi])
        bipolar_names.append(new_name)
    return np.vstack(bipolar), bipolar_names

# Usage:
# eeg_bipolar, bipolar_names = make_bipolar(eeg_resampled, ch_names)

# %%
def pre_process(eeg_data, fs_orig, fs_new, ch_names):
    eeg_resampled = resample_eeg(eeg_data, fs_orig, fs_new)
    eeg_filtered = apply_eeg_filters(eeg_resampled, fs_new)
    bp_eeg, bp_ch_names = make_bipolar(eeg_filtered, ch_names)
    return bp_eeg, bp_ch_names

# %%
import numpy as np

def burst_suppression_labels(x, fs, theta, tau=0.1047, agree_percent=0.60, min_supp_sec=0.5):
    """
    x: (n_channels, n_samples) in NU
    Returns:
      z_local:  (n_channels, n_samples) uint8, burst=1, suppression=0
      z_global: (n_samples,) uint8, burst=1, suppression=0
    """
    x = np.asarray(x, dtype=np.float64)
    n_ch, n_samp = x.shape

    beta = np.exp(-1.0 / (tau * fs))

    mu = x[:, 0].copy()
    v = np.zeros(n_ch, dtype=np.float64)

    z_local = np.zeros((n_ch, n_samp), dtype=np.uint8)
    z_local[:, 0] = (v >= theta).astype(np.uint8)

    for t in range(1, n_samp):
        xt = x[:, t]
        mu = beta * mu + (1.0 - beta) * xt
        v  = beta * v  + (1.0 - beta) * (xt - mu) ** 2

        # burst=1 if variance high enough
        z_local[:, t] = (v >= theta).astype(np.uint8)

    # Global vote: suppression if >= agree_percent channels are suppressing
    supp_frac = np.mean(z_local == 0, axis=0)
    z_global = (supp_frac < agree_percent).astype(np.uint8)  # burst=1 otherwise

    # Smoothing: suppressions shorter than min_supp_sec are flipped to burst
    min_len = int(round(min_supp_sec * fs))
    if min_len > 1:
        z = z_global.copy()
        t = 0
        while t < n_samp:
            if z[t] == 0:
                start = t
                while t < n_samp and z[t] == 0:
                    t += 1
                end = t
                if (end - start) < min_len:
                    z[start:end] = 1
            else:
                t += 1
        z_global = z

    return z_local, z_global

# %%
def guess_theta_nu2(x, factor=0.5):
    """
    x: (n_channels, n_samples) in NU
    Returns theta in NU^2.
    Increase factor => more suppression (harder to call bursts).
    Decrease factor => more bursts.
    """
    x = np.asarray(x, dtype=np.float64)
    per_ch_var = np.var(x, axis=1)
    return factor * np.median(per_ch_var)

# %%
import numpy as np

def robust_zscore_per_channel(x, eps=1e-12):
    # x: (n_channels, n_samples)
    med = np.median(x, axis=1, keepdims=True)
    mad = np.median(np.abs(x - med), axis=1, keepdims=True)
    sigma = 1.4826 * mad  # MAD -> std estimate if roughly normal
    return (x - med) / (sigma + eps)

# %%
import numpy as np

def compute_bsr_from_global_labels(z_global, fs, artifact_mask=None, window_sec=60):
    """
    Replicates Zhan (2018) BSR:
      r_t = 1 - (1/(window_sec*fs)) * sum(z_global over last window)
    where z_global is burst=1, suppression=0.

    If artifact_mask is provided, any window containing >=1 artifact sample => BSR undefined (np.nan).

    Inputs:
      z_global: (n_samples,) array-like of {0,1} with burst=1, suppression=0
      fs: sample rate (Hz)
      artifact_mask: optional (n_samples,) boolean array, True where artifact
      window_sec: 60 seconds in the thesis

    Returns:
      bsr: (n_samples,) float array, np.nan where undefined
    """
    z = np.asarray(z_global).astype(np.float64)
    n = z.size
    W = int(round(window_sec * fs))
    if W <= 0:
        raise ValueError("window_sec*fs must be >= 1")

    # Moving sum of bursts in the trailing window (including current sample)
    # Use prefix sums for O(n)
    csum = np.concatenate(([0.0], np.cumsum(z)))
    # sum over [t-W+1, t] for t>=W-1; for early t, sum over [0, t]
    burst_sum = csum[1:] - csum[np.maximum(0, np.arange(n) - W + 1)]

    # Convert to ratio: 1 - mean(burst_label) in window
    denom = np.minimum(np.arange(n) + 1, W).astype(np.float64)  # early windows are shorter
    bsr = 1.0 - (burst_sum / denom)

    # Artifact rule: if ANY artifact sample in the window -> undefined
    if artifact_mask is not None:
        a = np.asarray(artifact_mask, dtype=bool)
        if a.shape != (n,):
            raise ValueError("artifact_mask must have shape (n_samples,)")

        acsum = np.concatenate(([0], np.cumsum(a.astype(np.int64))))
        art_count = acsum[1:] - acsum[np.maximum(0, np.arange(n) - W + 1)]
        bsr[art_count > 0] = np.nan

    return bsr

# %%
import numpy as np

def burst_suppression_episodes_from_bsr(
    bsr, fs,
    *,
    bsr_thresh=0.50,        # paper: r_t >= 0.50
    bsr_window_sec=60,      # paper: 1 minute window used to define r_t
    merge_gap_sec=1.0,      # paper: delta = 1 second
    min_episode_sec=5.0     # paper: minimum episode duration 5 seconds
):
    """
    Inputs
    ------
    bsr : (n_samples,) float array in [0,1] (may contain np.nan for undefined windows)
    fs  : sampling rate (Hz) corresponding to bsr

    Returns
    -------
    episodes : list of (start_idx, end_idx) sample indices, inclusive start, exclusive end
               representing final merged + filtered burst suppression episodes.
    episode_mask : (n_samples,) bool array marking samples that belong to any episode.

    Implements Zhan (2018) Sec 3.3.3:
      - if r_t >= 0.50, label the range [t-60s, t] as burst suppression
      - episodes are contiguous BS ranges
      - merge episodes separated by <= 1 second
      - remove episodes shorter than 5 seconds
    """
    r = np.asarray(bsr, dtype=np.float64)
    n = r.size
    W = int(round(bsr_window_sec * fs))
    gap_max = int(round(merge_gap_sec * fs))
    min_len = int(round(min_episode_sec * fs))

    # Step 1: threshold BSR (undefined/NaN -> not episode)
    good = np.isfinite(r)
    bs_at_t = good & (r >= bsr_thresh)  # True at time t means "window ending at t qualifies"

    # Step 2: convert "bs_at_t" into a per-sample mask by backfilling the 60s window [t-W+1, t]
    bs_mask = np.zeros(n, dtype=bool)
    for t in np.flatnonzero(bs_at_t):
        start = max(0, t - W + 1)
        bs_mask[start:t + 1] = True

    # Helper: extract contiguous True runs from a boolean mask
    def _runs(mask):
        idx = np.flatnonzero(mask)
        if idx.size == 0:
            return []
        runs = []
        s = idx[0]
        prev = idx[0]
        for k in idx[1:]:
            if k == prev + 1:
                prev = k
            else:
                runs.append((s, prev + 1))  # [s, prev+1)
                s = k
                prev = k
        runs.append((s, prev + 1))
        return runs

    # Step 3: initial episodes = contiguous ranges in bs_mask
    episodes = _runs(bs_mask)

    # Step 4: merge episodes with gaps <= 1 sec
    if episodes:
        merged = [episodes[0]]
        for (s, e) in episodes[1:]:
            ps, pe = merged[-1]
            gap = s - pe
            if gap <= gap_max:
                merged[-1] = (ps, e)
            else:
                merged.append((s, e))
        episodes = merged

    # Step 5: filter episodes shorter than 5 sec
    episodes = [(s, e) for (s, e) in episodes if (e - s) >= min_len]

    # Final mask
    episode_mask = np.zeros(n, dtype=bool)
    for s, e in episodes:
        episode_mask[s:e] = True

    return episodes, episode_mask

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_bsr_multichannel(
    x, fs, z_global, bsr,
    *,
    artifact_mask=None,      # <-- add this
    ch_names=None,
    channels=None,
    start_s=0.0,
    duration_s=30.0,
    episodes=None,
    bsr_thresh=0.50,
    max_channels=18,
    spacing=None,
    shade_artifacts=True,
    shade_episodes=True,
):
    x = np.asarray(x)
    z_global = np.asarray(z_global).astype(np.uint8)
    bsr = np.asarray(bsr, dtype=float)

    n_ch, n_samp = x.shape
    if ch_names is None:
        ch_names = [f"ch{i}" for i in range(n_ch)]

    if channels is None:
        channels = list(range(min(n_ch, max_channels)))
    else:
        channels = list(channels)[:max_channels]

    start = int(round(start_s * fs))
    end = int(round((start_s + duration_s) * fs))
    start = max(0, min(start, n_samp))
    end = max(0, min(end, n_samp))
    if end <= start:
        raise ValueError("Bad window: end <= start")

    t = np.arange(start, end) / fs
    Xw = x[:, start:end]
    z = z_global[start:end]
    r = bsr[start:end]

    # episode mask
    ep_mask = np.zeros(end - start, dtype=bool)
    if episodes is not None:
        for (a_s, b_s) in episodes:
            a = int(round(a_s * fs))
            b = int(round(b_s * fs))
            a = max(a, start)
            b = min(b, end)
            if b > a:
                ep_mask[(a - start):(b - start)] = True
    else:
        ep_mask = np.isfinite(r) & (r >= bsr_thresh)

    burst_in_ep = ep_mask & (z == 1)

    # spacing
    sel = Xw[channels, :]
    robust_amp = np.percentile(np.abs(sel), 95)
    if spacing is None:
        spacing = 2.5 * robust_amp if robust_amp > 0 else 1.0

    fig, (ax0, ax1) = plt.subplots(
        2, 1, figsize=(13, 7), sharex=True,
        gridspec_kw={"height_ratios": [4, 1]}
    )

    y0 = 0
    y1 = spacing * (len(channels) - 1) + spacing

    # --- Artifact shading (light gray) ---
    if shade_artifacts and artifact_mask is not None:
        artifact_mask = np.asarray(artifact_mask, dtype=bool)
        if artifact_mask.shape[0] != n_samp:
            raise ValueError("artifact_mask must have length n_samples (same as x.shape[1])")
        artifact_mask_win = artifact_mask[start:end]

        ax0.fill_between(
            t, y0, y1,
            where=artifact_mask_win,
            step="pre",
            color="darkgray",
            alpha=0.25,
            label="Artifact"
        )

    # --- Episode shading (pink) + burst within episode (red) ---
    if shade_episodes:
        ax0.fill_between(
            t, y0, y1,
            where=ep_mask,
            step="pre",
            alpha=0.12,
            label="BS episode"
        )
        ax0.fill_between(
            t, y0, y1,
            where=burst_in_ep,
            step="pre",
            alpha=0.20,
            label="Burst within episode"
        )

    # stacked traces
    for row, ch in enumerate(channels):
        offset = spacing * (len(channels) - 1 - row)
        ax0.plot(t, Xw[ch, :] + offset, linewidth=0.8)
        ax0.text(
            t[0] - 0.01 * (t[-1] - t[0] + 1e-9),
            offset,
            ch_names[ch],
            va="center", ha="right", fontsize=9
        )

    ax0.set_ylim(-spacing * 0.5, y1 + spacing * 0.2)
    ax0.set_yticks([])
    ax0.set_ylabel("EEG (stacked)")
    ax0.set_title("Burst suppression visualization")

    # de-duplicate legend entries
    handles, labels = ax0.get_legend_handles_labels()
    uniq = dict(zip(labels, handles))
    ax0.legend(uniq.values(), uniq.keys(), loc="upper right")

    # bottom panel
    ax1.plot(t, z.astype(float), linewidth=1.0, label="z_global")
    ax1.plot(t, r, linewidth=1.0, label="BSR r_t")
    ax1.axhline(bsr_thresh, linestyle="--", linewidth=1.0, label=f"BSR threshold {bsr_thresh}")
    ax1.set_ylim(-0.05, 1.05)
    ax1.set_ylabel("z / BSR")
    ax1.set_xlabel("Time (seconds)")
    ax1.legend(loc="upper right")

    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import pandas as pd

def artifact_mask_from_sliding_windows_csv(
    csv_path: str,
    n_samples: int,
    fs: int,
    artifact_col: str = "has_artifact",
    window_sec: float = 10.0,
    step_sec: float = 2.0,
) -> np.ndarray:
    """
    CSV rows are produced every `step_sec` seconds, each decision based on a `window_sec` segment.
    Row i corresponds to time interval [i*step_sec, i*step_sec + window_sec).

    Returns:
      artifact_mask: (n_samples,) bool, True where artifact.
    """
    df = pd.read_csv(csv_path)
    if artifact_col not in df.columns:
        raise ValueError(f"CSV missing '{artifact_col}'. Found: {list(df.columns)}")

    labels = df[artifact_col].to_numpy().astype(bool)

    W = int(round(window_sec * fs))
    H = int(round(step_sec * fs))

    mask = np.zeros(n_samples, dtype=bool)

    for i, is_art in enumerate(labels):
        if not is_art:
            continue
        start = i * H
        end = start + W
        if start >= n_samples:
            break
        mask[start:min(end, n_samples)] = True

    return mask

# %%
def apply_artifact_to_bsr(bsr, artifact_mask, fs, win_sec=60.0):
    bsr = bsr.copy().astype(float)
    win = int(round(win_sec * fs))

    # any artifact in [t-win+1, t] => undefined
    # rolling "any" via cumulative sum
    art = artifact_mask.astype(np.int32)
    c = np.cumsum(np.r_[0, art])  # length n_samples+1
    n = len(artifact_mask)

    for t in range(n):
        lo = max(0, t - win + 1)
        hi = t + 1
        if (c[hi] - c[lo]) > 0:
            bsr[t] = np.nan
    return bsr

# %%
def blank_artifacts_for_plot(eeg, artifact_mask):
    eeg_plot = eeg.astype(float).copy()
    eeg_plot[:, artifact_mask] = np.nan   # shows as gaps/white in plots
    return eeg_plot

# %%
def window_mask(mask, start_samp, end_samp):
    """Extract mask for plotting window."""
    return mask[start_samp:end_samp]

# %%
import mne
import numpy as np

def plot_eeg_mne_fixed(eeg_uv, fs, ch_names, start=0, duration=30, scale_uv=200):
    eeg_uv = np.asarray(eeg_uv, dtype=np.float64)

    # Convert µV -> V for MNE
    eeg_v = eeg_uv * 1e-6

    info = mne.create_info(ch_names=ch_names, sfreq=fs, ch_types="eeg")
    raw = mne.io.RawArray(eeg_v, info)

    raw.plot(
        start=start,
        duration=duration,
        n_channels=min(len(ch_names), 12),
        scalings=dict(eeg=scale_uv * 1e-6),  # e.g., 200 µV display scale
        clipping=5.0,                        # clip extreme outliers in display
        remove_dc=True,                      # removes per-channel DC for viewing
        block=True
    )

# %%
eeg_unprocessed = load_mat_file("eeg_mat/0284_005_008_EEG.mat")
print(eeg_unprocessed)
# Out:
# [[  7125   7165   4267 ... -23026 -22543 -22100]
#  [  4290   3565   1028 ... -26523 -26523 -25718]
#  [  8742   9764   6032 ... -22594 -23003 -23258]
#  ...
#  [ 10316   9173   6938 ... -23257 -23049 -23153]
#  [  9667   9105   6969 ... -20683 -20852 -22257]
#  [  5418   4415   2363 ... -21359 -22123 -22218]]

# %%
fs_orig, ch_names, num_ch, units = load_hea_file("eeg_hea/0284_005_008_EEG")
print(ch_names, fs_orig)
# Out:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz'] 500

# %%
import wfdb

record = wfdb.rdheader("eeg_hea/0284_005_008_EEG")  # without extension
sig = record.p_signal          # physical units if gain is known
units = record.units
fs = record.fs
names = record.sig_name
print(sig, units, names)
# Out:
# None ['nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu', 'nu'] ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz']

# %%
plot_eeg_mne_fixed(eeg_unprocessed, fs_orig, ch_names, start=410, duration=30, scale_uv=20000)
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=221500
#     Range : 0 ... 221499 =      0.000 ...   442.998 secs
# Ready.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
fs_new = 200
eeg_processed, bp_ch_names = pre_process(eeg_unprocessed, fs_orig, fs_new, ch_names)
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=88600
#     Range : 0 ... 88599 =      0.000 ...   442.995 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# ...

# %%
print(eeg_processed)
# Out:
# [[-3.84891771e-12  8.77786396e+01  7.16648879e+01 ...  8.11057407e+01
#    8.98589732e+01 -5.42101086e-14]
#  [-3.22211333e-12  8.32759614e+01  9.91859242e+01 ...  3.06736118e+01
#    2.59378664e+01  2.64274280e-13]
#  [ 2.00238589e-12 -1.83178936e+01 -3.80118274e+01 ... -3.99463083e+01
#   -1.60907726e+01  6.77626358e-15]
#  ...
#  [ 3.21872520e-12  6.36311891e+01  5.23590912e+01 ...  1.71583934e+01
#    5.81786431e+01  1.45689667e-13]
#  [-1.71354765e-12 -2.78905487e+01 -6.13383918e+01 ...  1.85229113e+01
#    1.82748210e+01  3.04931861e-14]
#  [-3.04931861e-14  2.24242011e+01  3.29300651e+01 ...  6.68615515e+00
#    1.51501661e+01  2.01932655e-12]]

# %%
plot_eeg_mne_fixed(eeg_processed, fs_new, bp_ch_names, start=410, duration=30, scale_uv=20000)
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=88600
#     Range : 0 ... 88599 =      0.000 ...   442.995 secs
# Ready.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
import numpy as np

def describe(name, x):
    x = np.asarray(x)
    print(f"\n{name}")
    print(" dtype:", x.dtype, "shape:", x.shape)
    print(" min/max:", np.nanmin(x), np.nanmax(x))
    print(" p95(|x|):", np.nanpercentile(np.abs(x), 95))
    print(" p99(|x|):", np.nanpercentile(np.abs(x), 99))

describe("eeg_unprocessed (µV?)", eeg_unprocessed)
describe("eeg_processed (µV?)", eeg_processed)
# if you have it:
# describe("x_norm (unitless)", x_norm)
# Out:
# eeg_unprocessed (µV?)
#  dtype: int16 shape: (19, 221500)
#  min/max: -32767 32767
#  p95(|x|): 19184.0
#  p99(|x|): 24726.0
#
# eeg_processed (µV?)
#  dtype: float64 shape: (19, 88600)
#  min/max: -28541.238421108068 21306.015195209926
#  p95(|x|): 4020.412895858176
#  p99(|x|): 6406.15531050093

# %%
# alternate code using zscore method and theta = 1.75 from paper, DISCUSS WHICH IS BETTER
eeg_norm = robust_zscore_per_channel(eeg_processed)
# z_local, z_global = burst_suppression_labels(eeg_norm, fs_new, theta=1.75)
# print("global burst fraction:", z_global.mean())

# %%
z_local, z_global = burst_suppression_labels(eeg_norm, fs_new, theta=.6)

print("global burst fraction:", z_global.mean())
print(z_global.shape)
# Out:
# global burst fraction: 0.46330699774266365
# (88600,)

# %%
artifact_mask = artifact_mask_from_sliding_windows_csv(
    "sparcnet_labels+artifact_mask-wfdb_2s/training/0284/0284_005_008_final_labels_with_artifact.csv",
    n_samples=eeg_processed.shape[1],
    fs=fs_new,  
    artifact_col="has_artifact",
    window_sec=10.0,
    step_sec=2.0,
)

print("artifact fraction:", artifact_mask.mean())
# Out:
# artifact fraction: 0.022573363431151242

# %%
print("rows in csv:", pd.read_csv("sparcnet_labels+artifact_mask-wfdb_2s/training/0284/0284_005_008_final_labels_with_artifact.csv").shape[0])
print("expected step samples:", int(round(2*fs_new)))
print("expected window samples:", int(round(10*fs_new)))
print("artifact_mask length:", len(artifact_mask), "should equal n_samples:", eeg_processed.shape[1])
# Out:
# rows in csv: 217
# expected step samples: 400
# expected window samples: 2000
# artifact_mask length: 88600 should equal n_samples: 88600

# %%
bsr = compute_bsr_from_global_labels(z_global, fs_new, artifact_mask=artifact_mask, window_sec=60)
print(bsr)
print(bsr.shape)
# Out:
# [0.         0.         0.         ... 0.63166667 0.63166667 0.63166667]
# (88600,)

# %%
#bsr should be same length as z_global
episodes, ep_mask = burst_suppression_episodes_from_bsr(bsr, fs_new)

print("num episodes:", len(episodes))
print("first few (sec):", [(s/fs_new, e/fs_new) for s, e in episodes[:5]])
# Out:
# num episodes: 2
# first few (sec): [(np.float64(72.135), np.float64(224.0)), (np.float64(234.0), np.float64(443.0))]

# %%
plot_bsr_multichannel(
    x=eeg_processed,
    fs=fs_new,
    z_global=z_global,
    bsr=bsr,
    artifact_mask=artifact_mask,   # <-- important
    ch_names=bp_ch_names,
    start_s=215,
    duration_s=30
)
